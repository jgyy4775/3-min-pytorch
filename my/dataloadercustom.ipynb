# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import Dataset
from torch.utils.data import DataLoader

class CustomDataset(Dataset): ## Dataset 클래스 상속
	def __init__(self):
		self.x_train = [[70, 77, 72],
						[90, 85, 90],
						[86, 88, 87],
						[93, 95, 97],
						[70, 63, 67]]
		self.y_train = [[152],[185],[180],[196],[142]]
	
	def __len__(self):
		return len(self.x_train)
	
	def __getitem__(self, idx):
		x = torch.FloatTensor(self.x_train[idx])
		y = torch.FloatTensor(self.y_train[idx])
		return x, y

dataset = CustomDataset()
dataloader = DataLoader(dataset, batch_size=2, shuffle=True)
model = nn.Linear(3,1)
optimizer = torch.optim.SGD(model.parameters(), lr=1e-5)

total_epochs = 20
for epoch in range(total_epochs+1):
	for batch_idx, samples in enumerate(dataloader):
		x_train, y_train=samples
		prediction = model(x_train)
		loss=F.mse_loss(prediction, y_train)
	
		optimizer.zero_grad()
		loss.backward()
		optimizer.step()
		print('Epoch {:4d}/{} Barch {}/{} Cost: {:.6f}'.format(epoch, total_epochs, batch_idx+1,len(dataloader), loss.item()))
# Out:
# Epoch    0/20 Barch 1/3 Cost: 8994.660156
# Epoch    0/20 Barch 2/3 Cost: 4653.523926
# Epoch    0/20 Barch 3/3 Cost: 852.285217
# Epoch    1/20 Barch 1/3 Cost: 504.740509
# Epoch    1/20 Barch 2/3 Cost: 125.109299
# Epoch    1/20 Barch 3/3 Cost: 39.737926
# Epoch    2/20 Barch 1/3 Cost: 37.337708
# Epoch    2/20 Barch 2/3 Cost: 0.513126
# Epoch    2/20 Barch 3/3 Cost: 19.479504
# Epoch    3/20 Barch 1/3 Cost: 3.003052
# Epoch    3/20 Barch 2/3 Cost: 14.607178
# Epoch    3/20 Barch 3/3 Cost: 5.675033
# Epoch    4/20 Barch 1/3 Cost: 8.426268
# Epoch    4/20 Barch 2/3 Cost: 14.853946
# Epoch    4/20 Barch 3/3 Cost: 2.674505
# Epoch    5/20 Barch 1/3 Cost: 13.309541
# Epoch    5/20 Barch 2/3 Cost: 3.942036
# Epoch    5/20 Barch 3/3 Cost: 9.281495
# Epoch    6/20 Barch 1/3 Cost: 3.613737
# Epoch    6/20 Barch 2/3 Cost: 12.522085
# Epoch    6/20 Barch 3/3 Cost: 4.134970
# Epoch    7/20 Barch 1/3 Cost: 3.857313
# Epoch    7/20 Barch 2/3 Cost: 11.780966
# Epoch    7/20 Barch 3/3 Cost: 7.284134
# Epoch    8/20 Barch 1/3 Cost: 5.348237
# Epoch    8/20 Barch 2/3 Cost: 12.884319
# Epoch    8/20 Barch 3/3 Cost: 3.137508
# Epoch    9/20 Barch 1/3 Cost: 1.547247
# Epoch    9/20 Barch 2/3 Cost: 15.349318
# Epoch    9/20 Barch 3/3 Cost: 6.439479
# Epoch   10/20 Barch 1/3 Cost: 12.456084
# Epoch   10/20 Barch 2/3 Cost: 3.731256
# Epoch   10/20 Barch 3/3 Cost: 4.149006
# Epoch   11/20 Barch 1/3 Cost: 1.878111
# Epoch   11/20 Barch 2/3 Cost: 14.310452
# Epoch   11/20 Barch 3/3 Cost: 5.708378
# Epoch   12/20 Barch 1/3 Cost: 3.867955
# Epoch   12/20 Barch 2/3 Cost: 6.177677
# Epoch   12/20 Barch 3/3 Cost: 24.463964
# Epoch   13/20 Barch 1/3 Cost: 3.828197
# Epoch   13/20 Barch 2/3 Cost: 12.467871
# Epoch   13/20 Barch 3/3 Cost: 5.840081
# Epoch   14/20 Barch 1/3 Cost: 14.380555
# Epoch   14/20 Barch 2/3 Cost: 9.375876
# Epoch   14/20 Barch 3/3 Cost: 1.675953
# Epoch   15/20 Barch 1/3 Cost: 5.272382
# Epoch   15/20 Barch 2/3 Cost: 12.752302
# Epoch   15/20 Barch 3/3 Cost: 3.135184
# Epoch   16/20 Barch 1/3 Cost: 13.787881
# Epoch   16/20 Barch 2/3 Cost: 3.666528
# Epoch   16/20 Barch 3/3 Cost: 2.664632
# Epoch   17/20 Barch 1/3 Cost: 1.753284
# Epoch   17/20 Barch 2/3 Cost: 15.054841
# Epoch   17/20 Barch 3/3 Cost: 6.197620
# Epoch   18/20 Barch 1/3 Cost: 10.262337
# Epoch   18/20 Barch 2/3 Cost: 9.054681
# Epoch   18/20 Barch 3/3 Cost: 6.310724
# Epoch   19/20 Barch 1/3 Cost: 10.619110
# Epoch   19/20 Barch 2/3 Cost: 5.770699
# Epoch   19/20 Barch 3/3 Cost: 3.694483
# Epoch   20/20 Barch 1/3 Cost: 2.482278
# Epoch   20/20 Barch 2/3 Cost: 19.477760
# Epoch   20/20 Barch 3/3 Cost: 4.340002
